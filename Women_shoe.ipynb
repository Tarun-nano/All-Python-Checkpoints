# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
data=pd.read_csv("G:\Datasets\womens-shoes-prices\Datafiniti_Womens_Shoes_Jun19.csv")

# %%
data.head(2)
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AWpyySsJAGTnQPR7wNt4  2019-05-01T09:27:22Z  2019-05-01T09:27:22Z   NaN
# 1  AWpyyyb3AGTnQPR7wN-u  2019-05-01T09:27:19Z  2019-05-01T09:27:19Z   NaN
#
#              brand                                    categories  \
# 0  City Classified  Clothing,Shoes,Womens Shoes,All Womens Shoes
# 1         Skechers  Clothing,Shoes,Womens Shoes,All Womens Shoes
#
#   primaryCategories colors dimension     ean / upc  \
# 0             Shoes  Black       NaN  656000000000
# 1             Shoes  Taupe       NaN  192000000000
#
#                                            imageURLs  \
# 0  https://i5.walmartimages.com/asr/f0dc6cbd-fa38...
# 1                                                NaN
#
#                                                 keys manufacturer  \
# 0  walmart.com-2013PXX8GMN7,656143772191,06561437...          NaN
# 1  192283420528,0192283420528,walmart.com-21739WH...          NaN
#
#   manufacturerNumber                                               name  \
# 0                NaN  City Classified Stylish-S Women's Zipper Ankle...
# 1                NaN              Skechers Women'S You Radiate, Walking
#
#    prices.amountMax  prices.amountMin  prices.availability prices.color  \
# 0             29.95             29.95                 True        Black
# 1             84.00             84.00                 True        Taupe
#
#    prices.condition prices.currency  prices.dateAdded       prices.dateSeen  \
# 0               NaN             USD               NaN  2019-04-19T07:09:29Z
# 1               NaN             USD               NaN  2019-04-24T09:14:11Z
#
#   prices.isSale  prices.merchant prices.offer  prices.returnPolicy  \
# 0           NaN              NaN  Online only                  NaN
# 1           NaN              NaN  Online only                  NaN
#
#   prices.shipping prices.size  \
# 0             NaN           8
# 1             NaN      6 M US
#
#                                    prices.sourceURLs   sizes  \
# 0  https://www.walmart.com/ip/City-Classified-Sty...       8
# 1  https://www.walmart.com/ip/Skechers-Women-S-Yo...  6 M US
#
#                                           sourceURLs
# 0  https://www.walmart.com/ip/City-Classified-Sty...
# 1  https://www.walmart.com/ip/Skechers-Women-S-Yo...

# %%
data2=pd.read_csv("G:\Datasets\womens-shoes-prices\Datafiniti_Womens_Shoes.csv")

# %%
data2.head(2)
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
#
#   primaryCategories                          colors dimension           ean  \
# 0             Shoes  Silver,Cream Watercolor Floral       NaN           NaN
# 1             Shoes                            Grey       NaN  3.397705e+10
#
#                                            imageURLs  \
# 0  https://i5.walmartimages.com/asr/861ca6cf-fa55...
# 1  https://i5.walmartimages.com/asr/421de5d5-3a74...
#
#                                                 keys manufacturer  \
# 0  naturalizer/47147sc022,017136472311,womensnatu...          NaN
# 1  mukluks/00173650206,033977045743,muklukswomens...     Muk Luks
#
#   manufacturerNumber                                               name  \
# 0         47147SC022  Naturalizer Danya Women N/S Open Toe Synthetic...
# 1       0017365020-6                MUK LUKS Womens Jane Suede Moccasin
#
#    prices.amountMax  prices.amountMin prices.availability        prices.color  \
# 0             55.99             55.99                 NaN  UWomens  M Regular
# 1             47.00             35.25            In Stock                Grey
#
#   prices.condition prices.currency      prices.dateAdded  \
# 0              NaN             USD  2017-03-28T11:40:25Z
# 1              New             USD  2018-01-03T05:21:54Z
#
#                                      prices.dateSeen  prices.isSale  \
# 0  2017-03-25T09:19:24.819Z,2017-03-25T09:19:19.600Z          False
# 1  2017-12-08T14:24:00.000Z,2017-11-01T02:52:00.000Z           True
#
#   prices.merchant prices.offer  prices.returnPolicy prices.shipping  \
# 0   Overstock.com          NaN                  NaN             NaN
# 1     Walmart.com          NaN                  NaN        Standard
#
#   prices.size                                  prices.sourceURLs  \
# 0           S  https://www.overstock.com/Clothing-Shoes/Women...
# 1           6  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...
#
#                                                sizes  \
# 0  6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                         10,7,6,9,8
#
#                                           sourceURLs           upc weight
# 0  https://www.walmart.com/ip/Naturalizer-Danya-W...  017136472311    NaN
# 1  https://www.walmart.com/ip/MUK-LUKS-Womens-Jan...  033977045743    NaN

# %%
data3=pd.read_csv("G:\\Datasets\\womens-shoes-prices\\7210_1.csv")
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (13,16,18,22,24,32,33,40,41,47,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data3.head(2)
# Out:
#                      id asins   brand  \
# 0  AVpe__eOilAPnD_xSt-H   NaN  Novica
# 1  AVpe__eOilAPnD_xSt-H   NaN  Novica
#
#                                 categories  colors  count  \
# 0  Access.,Clothing,Shoes,Women's Clothing  Purple    NaN
# 1  Access.,Clothing,Shoes,Women's Clothing  Purple    NaN
#
#               dateAdded           dateUpdated  \
# 0  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 1  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
#
#                                         descriptions dimension  ean  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
#
#                                             features  flavors imageURLs  isbn  \
# 0  [{"key":"Pattern","value":["Solid"]},{"key":"W...      NaN       NaN   NaN
# 1  [{"key":"Pattern","value":["Solid"]},{"key":"W...      NaN       NaN   NaN
#
#                                                 keys manufacturer  \
# 0  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 1  handcraftedalpacablendpurplecharismasweaterper...          NaN
#
#   manufacturerNumber merchants  \
# 0             231516       NaN
# 1             231516       NaN
#
#                                                 name  prices.amountMin  \
# 0  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 1  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
#
#    prices.amountMax prices.availability prices.color prices.condition  \
# 0             62.99                 NaN          NaN              NaN
# 1             62.99                 NaN          NaN              NaN
#
#    prices.count prices.currency      prices.dateAdded  \
# 0           NaN             USD  2017-03-28T11:53:51Z
# 1           NaN             USD  2017-03-28T11:53:51Z
#
#             prices.dateSeen  prices.flavor  prices.isSale prices.merchant  \
# 0  2017-03-26T05:04:46.539Z            NaN          False   Overstock.com
# 1  2017-03-26T05:04:46.539Z            NaN          False   Overstock.com
#
#   prices.offer prices.returnPolicy prices.shipping prices.size  prices.source  \
# 0          NaN                 NaN             NaN           L            NaN
# 1          NaN                 NaN             NaN           M            NaN
#
#                                    prices.sourceURLs  prices.warranty  \
# 0  https://www.overstock.com/Worldstock-Fair-Trad...              NaN
# 1  https://www.overstock.com/Worldstock-Fair-Trad...              NaN
#
#                                           quantities  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
#
#                                              reviews sizes  \
# 0  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 1  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
#
#                                                 skus  \
# 0  [{"sourceURLs":["https://www.overstock.com/Wor...
# 1  [{"sourceURLs":["https://www.overstock.com/Wor...
#
#                                           sourceURLs  upc  vin  websiteIDs  \
# 0  https://www.overstock.com/Worldstock-Fair-Trad...  NaN  NaN         NaN
# 1  https://www.overstock.com/Worldstock-Fair-Trad...  NaN  NaN         NaN
#
#   weight  Unnamed: 48  Unnamed: 49  Unnamed: 50 Unnamed: 51
# 0    NaN          NaN          NaN          NaN         NaN
# 1    NaN          NaN          NaN          NaN         NaN

# %%
shoes=data3

# %%
shoes.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateAdded',
#        'dateUpdated', 'descriptions', 'dimension', 'ean', 'features',
#        'flavors', 'imageURLs', 'isbn', 'keys', 'manufacturer',
#        'manufacturerNumber', 'merchants', 'name', 'prices.amountMin',
#        'prices.amountMax', 'prices.availability', 'prices.color',
#        'prices.condition', 'prices.count', 'prices.currency',
#        'prices.dateAdded', 'prices.dateSeen', 'prices.flavor', 'prices.isSale',
#        'prices.merchant', 'prices.offer', 'prices.returnPolicy',
#        'prices.shipping', 'prices.size', 'prices.source', 'prices.sourceURLs',
#        'prices.warranty', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceURLs', 'upc', 'vin', 'websiteIDs', 'weight', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51'],
#       dtype='object')

# %%
shoes.shape
# Out:
# (33801, 52)

# %%
shoes.isnull().sum()
# Out:
# id                         0
# asins                  31379
# brand                    984
# categories                 0
# colors                 13957
# count                  33801
# dateAdded                  0
# dateUpdated                0
# descriptions            5376
# dimension              32624
# ean                    24023
# features                6620
# flavors                33801
# imageURLs              11492
# isbn                   33801
# keys                       0
# manufacturer           24522
# manufacturerNumber      2367
# merchants              18419
# name                       0
# prices.amountMin           0
# prices.amountMax           0
# prices.availability    33494
# prices.color           16380
# prices.condition       21786
# prices.count           33801
# prices.currency            0
# prices.dateAdded           0
# prices.dateSeen            0
# prices.flavor          33801
# prices.isSale              0
# prices.merchant         3875
# prices.offer           27003
# prices.returnPolicy    32427
# prices.shipping        29853
# prices.size            18410
# prices.source          33801
# prices.sourceURLs          0
# prices.warranty        33801
# quantities             15311
# reviews                29613
# sizes                  25199
# skus                   11666
# sourceURLs                 0
# upc                    23077
# vin                    33801
# websiteIDs             33801
# weight                 32538
# Unnamed: 48            33801
# Unnamed: 49            33801
# Unnamed: 50            33801
# Unnamed: 51            33800
# dtype: int64

# %%
shoes.drop(["Unnamed: 48","Unnamed: 49","Unnamed: 50","Unnamed: 51","vin","websiteIDs","weight","prices.warranty","prices.returnPolicy","prices.flavor","flavors","count","prices.source","isbn","prices.count","asins"],axis=1,inplace=True)

# %%
shoes.shape
# Out:
# (33801, 36)

# %%
shoes.columns
# Out:
# Index(['id', 'brand', 'categories', 'colors', 'dateAdded', 'dateUpdated',
#        'descriptions', 'dimension', 'ean', 'features', 'imageURLs', 'keys',
#        'manufacturer', 'manufacturerNumber', 'merchants', 'name',
#        'prices.amountMin', 'prices.amountMax', 'prices.availability',
#        'prices.color', 'prices.condition', 'prices.currency',
#        'prices.dateAdded', 'prices.dateSeen', 'prices.isSale',
#        'prices.merchant', 'prices.offer', 'prices.shipping', 'prices.size',
#        'prices.sourceURLs', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceURLs', 'upc'],
#       dtype='object')

# %%
shoes.isnull().sum()
# Out:
# id                         0
# brand                    984
# categories                 0
# colors                 13957
# dateAdded                  0
# dateUpdated                0
# descriptions            5376
# dimension              32624
# ean                    24023
# features                6620
# imageURLs              11492
# keys                       0
# manufacturer           24522
# manufacturerNumber      2367
# merchants              18419
# name                       0
# prices.amountMin           0
# prices.amountMax           0
# prices.availability    33494
# prices.color           16380
# prices.condition       21786
# prices.currency            0
# prices.dateAdded           0
# prices.dateSeen            0
# prices.isSale              0
# prices.merchant         3875
# prices.offer           27003
# prices.shipping        29853
# prices.size            18410
# prices.sourceURLs          0
# quantities             15311
# reviews                29613
# sizes                  25199
# skus                   11666
# sourceURLs                 0
# upc                    23077
# dtype: int64

# %%
shoes.head()
# Out:
#                      id   brand                               categories  \
# 0  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 1  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 2  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 3  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 4  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
#
#    colors             dateAdded           dateUpdated  \
# 0  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 1  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 2  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 3  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 4  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
#
#                                         descriptions dimension  ean  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
#
#                                             features imageURLs  \
# 0  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 1  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 2  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 3  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 4  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
#
#                                                 keys manufacturer  \
# 0  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 1  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 2  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 3  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 4  handcraftedalpacablendpurplecharismasweaterper...          NaN
#
#   manufacturerNumber merchants  \
# 0             231516       NaN
# 1             231516       NaN
# 2             231516       NaN
# 3             231516       NaN
# 4             231516       NaN
#
#                                                 name  prices.amountMin  \
# 0  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 1  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 2  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 3  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 4  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
#
#    prices.amountMax prices.availability prices.color prices.condition  \
# 0             62.99                 NaN          NaN              NaN
# 1             62.99                 NaN          NaN              NaN
# 2             62.99                 NaN          NaN              NaN
# 3             62.99                 NaN          NaN              NaN
# 4             62.99                 NaN          NaN              NaN
#
#   prices.currency      prices.dateAdded           prices.dateSeen  \
# 0             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 1             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 2             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 3             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 4             USD  2017-03-02T16:48:44Z  2017-02-08T07:38:48.129Z
#
#    prices.isSale prices.merchant prices.offer prices.shipping prices.size  \
# 0          False   Overstock.com          NaN             NaN           L
# 1          False   Overstock.com          NaN             NaN           M
# 2          False   Overstock.com          NaN             NaN           S
# 3          False   Overstock.com          NaN             NaN          XL
# 4           True   Overstock.com          NaN             NaN          XL
#
#                                    prices.sourceURLs  \
# 0  https://www.overstock.com/Worldstock-Fair-Trad...
# 1  https://www.overstock.com/Worldstock-Fair-Trad...
# 2  https://www.overstock.com/Worldstock-Fair-Trad...
# 3  https://www.overstock.com/Worldstock-Fair-Trad...
# 4  https://www.overstock.com/Worldstock-Fair-Trad...
#
#                                           quantities  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
#
#                                              reviews sizes  \
# 0  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 1  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 2  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 3  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 4  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
#
#                                                 skus  \
# 0  [{"sourceURLs":["https://www.overstock.com/Wor...
# 1  [{"sourceURLs":["https://www.overstock.com/Wor...
# 2  [{"sourceURLs":["https://www.overstock.com/Wor...
# 3  [{"sourceURLs":["https://www.overstock.com/Wor...
# 4  [{"sourceURLs":["https://www.overstock.com/Wor...
#
#                                           sourceURLs  upc
# 0  https://www.overstock.com/Worldstock-Fair-Trad...  NaN
# 1  https://www.overstock.com/Worldstock-Fair-Trad...  NaN
# 2  https://www.overstock.com/Worldstock-Fair-Trad...  NaN
# 3  https://www.overstock.com/Worldstock-Fair-Trad...  NaN
# 4  https://www.overstock.com/Worldstock-Fair-Trad...  NaN

# %%
# finding the mean of price columns grouped by brands

shoes_avg=shoes.groupby(by="brand")["prices.amountMin","prices.amountMax"].mean()
shoes_avg.head()
# Out:
#                  prices.amountMin  prices.amountMax
# brand
# 1 World Sarongs         19.763913         19.763913
# 143 GIRL                 8.794000          8.794000
# 143 Girl                25.993333         25.993333
# 2 Lips Too              46.950000         46.950000
# 361                     80.000000         80.000000

# %%
shoes_avg.dtypes
# Out:
# prices.amountMin    float64
# prices.amountMax    float64
# dtype: object

# %%
# this will show all the rows of our dataset 
pd.set_option("display.max_rows",None)

# %%
shoes_avg.head()
# Out:
#                  prices.amountMin  prices.amountMax
# brand
# 1 World Sarongs         19.763913         19.763913
# 143 GIRL                 8.794000          8.794000
# 143 Girl                25.993333         25.993333
# 2 Lips Too              46.950000         46.950000
# 361                     80.000000         80.000000

# %%
shoes_avg["Average_Price"]=(shoes_avg["prices.amountMin"]+shoes_avg["prices.amountMax"])/2

# %%
shoes_avg.head()
# Out:
#                  prices.amountMin  prices.amountMax  Average_Price
# brand
# 1 World Sarongs         19.763913         19.763913      19.763913
# 143 GIRL                 8.794000          8.794000       8.794000
# 143 Girl                25.993333         25.993333      25.993333
# 2 Lips Too              46.950000         46.950000      46.950000
# 361                     80.000000         80.000000      80.000000

# %%
# sorting the values so as to find the top ten brands with highest average price

# %%
shoes_avg.sort_values(by="Average_Price",ascending=False).head(10)
# Out:
#                      prices.amountMin  prices.amountMax  Average_Price
# brand
# JewelsObsession           3322.190000       3322.190000    3322.190000
# Valentino                 1186.998000       1186.998000    1186.998000
# Simone Rocha              1120.000000       1120.000000    1120.000000
# MALONE SOULIERS           1100.000000       1100.000000    1100.000000
# Nicholas Kirkwood         1095.000000       1095.000000    1095.000000
# Marni                      963.333333        963.333333     963.333333
# Paul Andrew                895.000000        895.000000     895.000000
# Christian Louboutin        867.333333        867.333333     867.333333
# Giuseppe Zanotti           851.666667        851.666667     851.666667
# Givenchy                   850.000000        850.000000     850.000000

# %%
# this will help us to check the skewness of out price distribution and as we can see our dataset is right skewed

sns.distplot(shoes_avg["Average_Price"],kde=True)

# %%
sns.boxplot(shoes_avg["Average_Price"])

# %%
shoes_avg.describe()    # this will identify the mean of Average price column along with other details
# Out:
#        prices.amountMin  prices.amountMax  Average_Price
# count       1360.000000       1360.000000    1360.000000
# mean          94.356546         96.895302      95.625924
# std          159.728087        164.346284     160.870705
# min            0.990000          0.990000       0.990000
# 25%           31.992500         32.468269      32.107500
# 50%           50.945000         51.555000      51.207069
# 75%           90.000000         93.980000      92.437344
# max         3322.190000       3322.190000    3322.190000

# %%
# lets plot to show the brandwise no of shoes that have their average price above mean average price

# %%
sns.countplot(shoes_avg["Average_Price"]>95.62)

# %%
shoes_avg.head()
# Out:
#                  prices.amountMin  prices.amountMax  Average_Price
# brand
# 1 World Sarongs         19.763913         19.763913      19.763913
# 143 GIRL                 8.794000          8.794000       8.794000
# 143 Girl                25.993333         25.993333      25.993333
# 2 Lips Too              46.950000         46.950000      46.950000
# 361                     80.000000         80.000000      80.000000

# %%
shoes.head()
# Out:
#                      id   brand                               categories  \
# 0  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 1  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 2  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 3  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 4  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
#
#    colors             dateAdded           dateUpdated  \
# 0  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 1  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 2  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 3  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 4  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
#
#                                         descriptions dimension  ean  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
#
#                                             features imageURLs  \
# 0  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 1  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 2  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 3  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 4  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
#
#                                                 keys manufacturer  \
# 0  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 1  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 2  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 3  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 4  handcraftedalpacablendpurplecharismasweaterper...          NaN
#
#   manufacturerNumber merchants  \
# 0             231516       NaN
# 1             231516       NaN
# 2             231516       NaN
# 3             231516       NaN
# 4             231516       NaN
#
#                                                 name  prices.amountMin  \
# 0  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 1  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 2  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 3  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 4  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
#
#    prices.amountMax prices.availability prices.color prices.condition  \
# 0             62.99                 NaN          NaN              NaN
# 1             62.99                 NaN          NaN              NaN
# 2             62.99                 NaN          NaN              NaN
# 3             62.99                 NaN          NaN              NaN
# 4             62.99                 NaN          NaN              NaN
#
#   prices.currency      prices.dateAdded           prices.dateSeen  \
# 0             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 1             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 2             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 3             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 4             USD  2017-03-02T16:48:44Z  2017-02-08T07:38:48.129Z
#
#    prices.isSale prices.merchant prices.offer prices.shipping prices.size  \
# 0          False   Overstock.com          NaN             NaN           L
# 1          False   Overstock.com          NaN             NaN           M
# 2          False   Overstock.com          NaN             NaN           S
# 3          False   Overstock.com          NaN             NaN          XL
# 4           True   Overstock.com          NaN             NaN          XL
#
#                                    prices.sourceURLs  \
# 0  https://www.overstock.com/Worldstock-Fair-Trad...
# 1  https://www.overstock.com/Worldstock-Fair-Trad...
# 2  https://www.overstock.com/Worldstock-Fair-Trad...
# 3  https://www.overstock.com/Worldstock-Fair-Trad...
# 4  https://www.overstock.com/Worldstock-Fair-Trad...
#
#                                           quantities  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
#
#                                              reviews sizes  \
# 0  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 1  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 2  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 3  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 4  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
#
#                                                 skus  \
# 0  [{"sourceURLs":["https://www.overstock.com/Wor...
# 1  [{"sourceURLs":["https://www.overstock.com/Wor...
# 2  [{"sourceURLs":["https://www.overstock.com/Wor...
# 3  [{"sourceURLs":["https://www.overstock.com/Wor...
# 4  [{"sourceURLs":["https://www.overstock.com/Wor...
#
#                                           sourceURLs  upc
# 0  https://www.overstock.com/Worldstock-Fair-Trad...  NaN
# 1  https://www.overstock.com/Worldstock-Fair-Trad...  NaN
# 2  https://www.overstock.com/Worldstock-Fair-Trad...  NaN
# 3  https://www.overstock.com/Worldstock-Fair-Trad...  NaN
# 4  https://www.overstock.com/Worldstock-Fair-Trad...  NaN

# %%
shoes.columns
# Out:
# Index(['id', 'brand', 'categories', 'colors', 'dateAdded', 'dateUpdated',
#        'descriptions', 'dimension', 'ean', 'features', 'imageURLs', 'keys',
#        'manufacturer', 'manufacturerNumber', 'merchants', 'name',
#        'prices.amountMin', 'prices.amountMax', 'prices.availability',
#        'prices.color', 'prices.condition', 'prices.currency',
#        'prices.dateAdded', 'prices.dateSeen', 'prices.isSale',
#        'prices.merchant', 'prices.offer', 'prices.shipping', 'prices.size',
#        'prices.sourceURLs', 'quantities', 'reviews', 'sizes', 'skus',
#        'sourceURLs', 'upc'],
#       dtype='object')

# %%
shoes["prices.isSale"].value_counts()
# Out:
# False    27797
# True      6004
# Name: prices.isSale, dtype: int64

# %%
shoes["Average_Price"]=(shoes["prices.amountMin"]+shoes["prices.amountMax"])/2

# %%
shoes.head()
# Out:
#                      id   brand                               categories  \
# 0  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 1  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 2  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 3  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 4  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
#
#    colors             dateAdded           dateUpdated  \
# 0  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 1  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 2  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 3  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 4  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
#
#                                         descriptions dimension  ean  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
#
#                                             features imageURLs  \
# 0  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 1  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 2  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 3  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 4  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
#
#                                                 keys manufacturer  \
# 0  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 1  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 2  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 3  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 4  handcraftedalpacablendpurplecharismasweaterper...          NaN
#
#   manufacturerNumber merchants  \
# 0             231516       NaN
# 1             231516       NaN
# 2             231516       NaN
# 3             231516       NaN
# 4             231516       NaN
#
#                                                 name  prices.amountMin  \
# 0  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 1  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 2  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 3  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 4  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
#
#    prices.amountMax prices.availability prices.color prices.condition  \
# 0             62.99                 NaN          NaN              NaN
# 1             62.99                 NaN          NaN              NaN
# 2             62.99                 NaN          NaN              NaN
# 3             62.99                 NaN          NaN              NaN
# 4             62.99                 NaN          NaN              NaN
#
#   prices.currency      prices.dateAdded           prices.dateSeen  \
# 0             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 1             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 2             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 3             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 4             USD  2017-03-02T16:48:44Z  2017-02-08T07:38:48.129Z
#
#    prices.isSale prices.merchant prices.offer prices.shipping prices.size  \
# 0          False   Overstock.com          NaN             NaN           L
# 1          False   Overstock.com          NaN             NaN           M
# 2          False   Overstock.com          NaN             NaN           S
# 3          False   Overstock.com          NaN             NaN          XL
# 4           True   Overstock.com          NaN             NaN          XL
#
#                                    prices.sourceURLs  \
# 0  https://www.overstock.com/Worldstock-Fair-Trad...
# 1  https://www.overstock.com/Worldstock-Fair-Trad...
# 2  https://www.overstock.com/Worldstock-Fair-Trad...
# 3  https://www.overstock.com/Worldstock-Fair-Trad...
# 4  https://www.overstock.com/Worldstock-Fair-Trad...
#
#                                           quantities  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
#
#                                              reviews sizes  \
# 0  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 1  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 2  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 3  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 4  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
#
#                                                 skus  \
# 0  [{"sourceURLs":["https://www.overstock.com/Wor...
# 1  [{"sourceURLs":["https://www.overstock.com/Wor...
# 2  [{"sourceURLs":["https://www.overstock.com/Wor...
# 3  [{"sourceURLs":["https://www.overstock.com/Wor...
# 4  [{"sourceURLs":["https://www.overstock.com/Wor...
#
#                                           sourceURLs  upc  Average_Price
# 0  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 1  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 2  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 3  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 4  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99

# %%
# lets found out the price gap between the lowest and highest prices grouped by brand

# %%
shoes_avg.head()
# Out:
#                  prices.amountMin  prices.amountMax  Average_Price
# brand
# 1 World Sarongs         19.763913         19.763913      19.763913
# 143 GIRL                 8.794000          8.794000       8.794000
# 143 Girl                25.993333         25.993333      25.993333
# 2 Lips Too              46.950000         46.950000      46.950000
# 361                     80.000000         80.000000      80.000000

# %%
shoes_avg.columns
# Out:
# Index(['prices.amountMin', 'prices.amountMax', 'Average_Price'], dtype='object')

# %%
shoes_avg["Price Gap"]=shoes_avg["prices.amountMax"]-shoes_avg["prices.amountMin"]

# %%
# These are the top 10 brands that have the largest price gaps between their highest and lowest prices

# %%
shoes_avg.sort_values(by="Price Gap",ascending=False).head(10)
# Out:
#                    prices.amountMin  prices.amountMax  Average_Price  \
# brand
# Teva                      65.866000        1355.57800     710.722000
# Babolat                   39.950000         595.49000     317.720000
# Danner                   142.325000         364.95000     253.637500
# Muck Boot                 56.440000         180.15000     118.295000
# SCOTT                     53.614000         140.00000      96.807000
# Stella McCartney         810.000000         885.00000     847.500000
# Tony Lama                154.990000         229.95000     192.470000
# Sanita                    75.332500         142.54750     108.940000
# Callaway Footwear         60.950000         119.99000      90.470000
# Vibram                    91.583939         143.11697     117.350455
#
#                     Price Gap
# brand
# Teva               1289.71200
# Babolat             555.54000
# Danner              222.62500
# Muck Boot           123.71000
# SCOTT                86.38600
# Stella McCartney     75.00000
# Tony Lama            74.96000
# Sanita               67.21500
# Callaway Footwear    59.04000
# Vibram               51.53303

# %%
# comparing highest 10 entries of Price columns

shoes_avg.sort_values(by="Price Gap",ascending=False).head(10).plot(kind="bar",stacked=True)

# %%
shoes.head()
# Out:
#                      id   brand                               categories  \
# 0  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 1  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 2  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 3  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 4  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
#
#    colors             dateAdded           dateUpdated  \
# 0  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 1  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 2  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 3  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 4  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
#
#                                         descriptions dimension  ean  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
#
#                                             features imageURLs  \
# 0  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 1  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 2  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 3  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 4  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
#
#                                                 keys manufacturer  \
# 0  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 1  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 2  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 3  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 4  handcraftedalpacablendpurplecharismasweaterper...          NaN
#
#   manufacturerNumber merchants  \
# 0             231516       NaN
# 1             231516       NaN
# 2             231516       NaN
# 3             231516       NaN
# 4             231516       NaN
#
#                                                 name  prices.amountMin  \
# 0  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 1  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 2  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 3  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 4  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
#
#    prices.amountMax prices.availability prices.color prices.condition  \
# 0             62.99                 NaN          NaN              NaN
# 1             62.99                 NaN          NaN              NaN
# 2             62.99                 NaN          NaN              NaN
# 3             62.99                 NaN          NaN              NaN
# 4             62.99                 NaN          NaN              NaN
#
#   prices.currency      prices.dateAdded           prices.dateSeen  \
# 0             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 1             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 2             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 3             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 4             USD  2017-03-02T16:48:44Z  2017-02-08T07:38:48.129Z
#
#    prices.isSale prices.merchant prices.offer prices.shipping prices.size  \
# 0          False   Overstock.com          NaN             NaN           L
# 1          False   Overstock.com          NaN             NaN           M
# 2          False   Overstock.com          NaN             NaN           S
# 3          False   Overstock.com          NaN             NaN          XL
# 4           True   Overstock.com          NaN             NaN          XL
#
#                                    prices.sourceURLs  \
# 0  https://www.overstock.com/Worldstock-Fair-Trad...
# 1  https://www.overstock.com/Worldstock-Fair-Trad...
# 2  https://www.overstock.com/Worldstock-Fair-Trad...
# 3  https://www.overstock.com/Worldstock-Fair-Trad...
# 4  https://www.overstock.com/Worldstock-Fair-Trad...
#
#                                           quantities  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
#
#                                              reviews sizes  \
# 0  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 1  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 2  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 3  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 4  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
#
#                                                 skus  \
# 0  [{"sourceURLs":["https://www.overstock.com/Wor...
# 1  [{"sourceURLs":["https://www.overstock.com/Wor...
# 2  [{"sourceURLs":["https://www.overstock.com/Wor...
# 3  [{"sourceURLs":["https://www.overstock.com/Wor...
# 4  [{"sourceURLs":["https://www.overstock.com/Wor...
#
#                                           sourceURLs  upc  Average_Price
# 0  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 1  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 2  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 3  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 4  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99

# %%
# applying Annova test to check if brand value has impact on Average Price on our data

# %%
import scipy.stats as stats
import statsmodels.api as sms
import statsmodels.formula.api as statsmodels
from statsmodels.formula.api import ols

# %%
shoes_ol=shoes[["brand","Average_Price"]]

# %%
shoes_ols=shoes_ol.sort_values(by="brand")
shoes_ols.head()
# Out:
#                  brand  Average_Price
# 24198  1 World Sarongs          32.74
# 7534   1 World Sarongs          27.99
# 8006   1 World Sarongs          20.12
# 8007   1 World Sarongs          20.12
# 8008   1 World Sarongs          14.08

# %%
n = 3
dfn = n-1

dfd = shoes_ols["brand"].shape[0]-2
dfd
# Out:
# 33799

# %%
stats.f.ppf(1-0.05, dfn=dfn, dfd=dfd)
# Out:
# 2.995997812259596

# %%
model_b = ols("Average_Price~brand",data=shoes).fit()

# %%
print(sms.stats.anova_lm(model_b))
# Out:
#                df        sum_sq        mean_sq          F  PR(>F)
# brand      1359.0  5.565823e+08  409552.817538  85.876976     0.0
# Residual  31457.0  1.500205e+08    4769.064254        NaN     NaN

# %%
# according to this brand has no impact on the average price of our shoes which seems a little fishy

# %%
shoes["brand"].value_counts().shape
# Out:
# (1360,)

# %%
model_g = ols("Average_Price~colors",data=shoes).fit()

# %%
print(sms.stats.anova_lm(model_g))
# Out:
#                df        sum_sq        mean_sq          F  PR(>F)
# colors     2064.0  3.379148e+08  163718.431867  12.616602     0.0
# Residual  17779.0  2.307079e+08   12976.428642        NaN     NaN

# %%
shoes[["brand","dateAdded","Average_Price"]].head()
# Out:
#     brand             dateAdded  Average_Price
# 0  Novica  2017-02-03T22:06:24Z          62.99
# 1  Novica  2017-02-03T22:06:24Z          62.99
# 2  Novica  2017-02-03T22:06:24Z          62.99
# 3  Novica  2017-02-03T22:06:24Z          62.99
# 4  Novica  2017-02-03T22:06:24Z          62.99

# %%
# now lets see how we can fill the null values of brand columns

# here's the idea , we can extract the brand name string from prices.sourceURLs but in order to do so we have to create a local data frame and then use split function

# %%
shoes["prices.sourceURLs"][12]
# Out:
# 'https://www.amazon.ca/SNEED--Womens-Leatherette-Paillette-blue-us1/dp/B01FJMV6S8'

# %%
shoes[["brand","prices.sourceURLs"]].head()
# Out:
#     brand                                  prices.sourceURLs
# 0  Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 1  Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 2  Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 3  Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 4  Novica  https://www.overstock.com/Worldstock-Fair-Trad...

# %%
shoes_strip=shoes[["brand","prices.sourceURLs"]]   # local dataframe

# %%
shoes_strip["Stripcol"]=shoes["prices.sourceURLs"].str.split("-").str[0]     # splitting the URL at "-"
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
shoes_strip.head(15)
# Out:
#                brand                                  prices.sourceURLs  \
# 0             Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 1             Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 2             Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 3             Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 4             Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 5             Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 6             Novica  https://www.overstock.com/Worldstock-Fair-Trad...
# 7       Pedi Couture  https://www.walmart.com/ip/PEDI-COUTURE-Women-...
# 8   ANNE KLEIN SPORT  http://www.walmart.com/ip/Anne-Klein-Sport-Per...
# 9   ANNE KLEIN SPORT  http://www.walmart.com/ip/Anne-Klein-Sport-Per...
# 10        BEAUTIFEET  https://www.walmart.com/ip/Sof-Comfort-Women-s...
# 11        BEAUTIFEET  http://www.walmart.com/ip/Sof-Comfort-Women-s-...
# 12               NaN  https://www.amazon.ca/SNEED--Womens-Leatherett...
# 13       Marc Fisher  https://www.walmart.com/ip/Marc-Fisher-Fawna-W...
# 14       Marc Fisher  https://www.walmart.com/ip/Marc-Fisher-Fawna-W...
#
#                                 Stripcol
# 0   https://www.overstock.com/Worldstock
# 1   https://www.overstock.com/Worldstock
# 2   https://www.overstock.com/Worldstock
# 3   https://www.overstock.com/Worldstock
# 4   https://www.overstock.com/Worldstock
# 5   https://www.overstock.com/Worldstock
# 6   https://www.overstock.com/Worldstock
# 7        https://www.walmart.com/ip/PEDI
# 8         http://www.walmart.com/ip/Anne
# 9         http://www.walmart.com/ip/Anne
# 10        https://www.walmart.com/ip/Sof
# 11         http://www.walmart.com/ip/Sof
# 12           https://www.amazon.ca/SNEED
# 13       https://www.walmart.com/ip/Marc
# 14       https://www.walmart.com/ip/Marc

# %%
shoes_strip["Stripcol"]=shoes_strip["Stripcol"].str.split("/").str[-1]     # again splitting the URL ar "/" and -1 indicates we start from right
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
shoes_strip.head(50)
# Out:
#                          brand  \
# 0                       Novica
# 1                       Novica
# 2                       Novica
# 3                       Novica
# 4                       Novica
# 5                       Novica
# 6                       Novica
# 7                 Pedi Couture
# 8             ANNE KLEIN SPORT
# 9             ANNE KLEIN SPORT
# 10                  BEAUTIFEET
# 11                  BEAUTIFEET
# 12                         NaN
# 13                 Marc Fisher
# 14                 Marc Fisher
# 15                 Marc Fisher
# 16                    Caparros
# 17                    Caparros
# 18                    Caparros
# 19  INC International Concepts
# 20  INC International Concepts
# 21  INC International Concepts
# 22                        Lugz
# 23                        Lugz
# 24                        Lugz
# 25                        Lugz
# 26                    Skechers
# 27                    Skechers
# 28                    Skechers
# 29                    Skechers
# 30                    Skechers
# 31                DbDk Fashion
# 32                DbDk Fashion
# 33                DbDk Fashion
# 34                    Collonil
# 35                Vince Camuto
# 36                Vince Camuto
# 37                       Bloch
# 38                Michael Kors
# 39                        Nike
# 40                   Wild Diva
# 41                   Wild Diva
# 42                   Wild Diva
# 43                   Wild Diva
# 44                    SKECHERS
# 45                    SKECHERS
# 46               Pleaser Shoes
# 47               Pleaser Shoes
# 48                 Faded Glory
# 49                 Faded Glory
#
#                                     prices.sourceURLs    Stripcol
# 0   https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 1   https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 2   https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 3   https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 4   https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 5   https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 6   https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 7   https://www.walmart.com/ip/PEDI-COUTURE-Women-...        PEDI
# 8   http://www.walmart.com/ip/Anne-Klein-Sport-Per...        Anne
# 9   http://www.walmart.com/ip/Anne-Klein-Sport-Per...        Anne
# 10  https://www.walmart.com/ip/Sof-Comfort-Women-s...         Sof
# 11  http://www.walmart.com/ip/Sof-Comfort-Women-s-...         Sof
# 12  https://www.amazon.ca/SNEED--Womens-Leatherett...       SNEED
# 13  https://www.walmart.com/ip/Marc-Fisher-Fawna-W...        Marc
# 14  https://www.walmart.com/ip/Marc-Fisher-Fawna-W...        Marc
# 15  https://www.walmart.com/ip/Marc-Fisher-Fawna-W...        Marc
# 16  https://www.walmart.com/ip/Caparros-Karissa-Wo...    Caparros
# 17  https://www.walmart.com/ip/Caparros-Karissa-Wo...    Caparros
# 18  https://www.walmart.com/ip/Caparros-Karissa-Wo...    Caparros
# 19  https://www.walmart.com/ip/INC-International-C...         INC
# 20  https://www.walmart.com/ip/INC-International-C...         INC
# 21  https://www.walmart.com/ip/INC-International-C...         INC
# 22  http://www.overstock.com/Clothing-Shoes/Lugz-W...    Clothing
# 23  http://www.overstock.com/Clothing-Shoes/Lugz-W...    Clothing
# 24  https://www.overstock.com/Clothing-Shoes/Lugz-...    Clothing
# 25  http://www.overstock.com/Clothing-Shoes/Lugz-W...    Clothing
# 26  http://www.overstock.com/Clothing-Shoes/Womens...    Clothing
# 27  https://www.overstock.com/Clothing-Shoes/Women...    Clothing
# 28  https://www.overstock.com/Clothing-Shoes/Women...    Clothing
# 29  https://www.overstock.com/Clothing-Shoes/Women...    Clothing
# 30  https://www.overstock.com/Clothing-Shoes/Women...    Clothing
# 31  https://www.walmart.com/ip/DbDk-Fashion-Meira-...        DbDk
# 32  http://www.walmart.com/ip/DbDk-Fashion-Meira-4...        DbDk
# 33  https://www.walmart.com/ip/DbDk-Fashion-Meira-...        DbDk
# 34  http://www.amazon.ca/Crepe-Rubber-Nubuck-Collo...       Crepe
# 35               https://www.walmart.com/ip/152617365   152617365
# 36               https://www.walmart.com/ip/152617365   152617365
# 37  https://www.walmart.com/ip/Bloch-Women-Twist-D...       Bloch
# 38  http://www.ebay.com/itm/Michael-Kors-FULTON-Ri...     Michael
# 39  http://www.sportsauthority.com/Nike-Womens-Kai...        Nike
# 40  https://www.overstock.com/Clothing-Shoes/Women...    Clothing
# 41  http://www.overstock.com/Clothing-Shoes/Womens...    Clothing
# 42  http://www.overstock.com/Clothing-Shoes/Womens...    Clothing
# 43  https://www.overstock.com/Clothing-Shoes/Women...    Clothing
# 44  https://www.walmart.com/ip/SKECHERS-76033EW-B-...    SKECHERS
# 45  https://www.walmart.com/ip/SKECHERS-76033EW-B-...    SKECHERS
# 46  https://www.walmart.com/ip/Womens-Halloween-Se...      Womens
# 47  https://www.walmart.com/ip/Womens-Halloween-Se...      Womens
# 48  http://www.walmart.com/ip/Faded-Glory-Women-s-...       Faded
# 49  http://www.walmart.com/ip/Faded-Glory-Women-s-...       Faded

# %%
shoes_strip[shoes_strip["Stripcol"]=="SNEED"].count()
# Out:
# brand                  0
# prices.sourceURLs    161
# Stripcol             161
# dtype: int64

# %%
for i in range(0,len(shoes_strip["Stripcol"])):
    if shoes_strip["Stripcol"][i]=="SNEED" :
        shoes_strip["brand"][i]="SNEED"
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
shoes_strip["brand"].isnull().sum()
# Out:
# 823

# %%
# grouping the brand=null dataframe on the basis of brand 
shoes_strip[shoes_strip["brand"].isnull()].groupby(by="Stripcol").first()
# Out:
#                     brand                                  prices.sourceURLs
# Stripcol
# AIU                   NaN  https://www.amazon.ca/AIU-Platform-Fashion-Sne...
# ANKLE                 NaN  http://www.amazon.ca/ANKLE-FLEECE-LINED-BLACK-...
# ASICS                 NaN  http://www.amazon.ca/ASICS-Womens-GEL-Resoluti...
# Adidas                NaN  https://www.amazon.ca/Adidas-Stan-Smith-womens...
# Adult                 NaN  https://www.amazon.ca/Adult-Womens-Leather-Sho...
# Adults                NaN  https://www.amazon.ca/Adults-Womens-Ballet-Lea...
# Amblers               NaN  http://www.amazon.co.uk/Amblers-Steel-Safety-G...
# Ariat                 NaN  http://www.amazon.ca/Ariat-Womens-Tombstone-We...
# Asics                 NaN  https://www.amazon.ca/Asics-Solution-Womens-Te...
# Babihaus              NaN  https://www.amazon.ca/Babihaus-Leather-Fashion...
# Ballet                NaN  https://www.amazon.ca/Ballet-Pointe-Rhythmic-G...
# Blancho               NaN  http://www.amazon.ca/Blancho-Women-Shoes-Wedge...
# Blazin                NaN  http://www.amazon.ca/Blazin-Roxx-Ladies-Embroi...
# BlueFish              NaN  https://www.amazon.ca/BlueFish-Comfort-Fashion...
# Breathable            NaN  https://www.amazon.ca/Breathable-Comfort-Fashi...
# Brinley               NaN  http://www.walmart.com/ip/Brinley-Co.-Womens-F...
# CXYY                  NaN  https://www.amazon.ca/CXYY-Leather-sandals-sum...
# Canvas                NaN  https://www.amazon.ca/Canvas-Womens-Comfort-Fa...
# Capezio               NaN  http://www.amazon.com/Capezio-Womens-footUndee...
# ChunTou               NaN  https://www.amazon.ca/ChunTou-female-leather-r...
# Closed                NaN  https://www.amazon.ca/Closed-Bowknot-Wedding-W...
# Comfort               NaN  https://www.amazon.ca/Comfort-Fashion-Sneakers...
# Comfortable           NaN  https://www.amazon.ca/Comfortable-Leather-Loaf...
# Creepers              NaN  https://www.amazon.ca/Creepers-Platforms-Fashi...
# Customizable          NaN  https://www.amazon.ca/Customizable-Customized-...
# Customized            NaN  https://www.amazon.ca/Customized-Sparkling-Gli...
# DONNA                 NaN  http://www.amazon.ca/DONNA-Suede-Stilleto-Cour...
# DOrsay                NaN  https://www.amazon.ca/DOrsay-Two-Piece-Wedding...
# Diadora               NaN  https://www.amazon.ca/Diadora-Heritage-Vintage...
# Espadrilles           NaN  https://www.amazon.ca/Espadrilles-Canvas-Loafe...
# FEYNSINN              NaN  https://www.amazon.ca/FEYNSINN-crossbody-shoul...
# FILLE                 NaN  https://www.amazon.ca/FILLE-PATRE-Acepality-Pi...
# FRONT                 NaN  http://www.amazon.ca/FRONT-BLACK-LARGE-FLEECE-...
# Fashion               NaN  https://www.amazon.ca/Fashion-Sneakers-Outdoor...
# Faux                  NaN  http://www.amazon.ca/Faux-Suede-Stiletto-Court...
# Gleader               NaN  http://www.amazon.ca/Gleader-Modern-Canvas-Bal...
# H051                  NaN  http://www.amazon.ca/H051-Faux-Suede-Wedge-Sho...
# HEAD                  NaN  http://www.amazon.ca/HEAD-274115-110-Revolt-Wh...
# HONEY                 NaN  http://www.amazon.ca/HONEY-Patent-Leather-Wedg...
# Hot                   NaN  http://www.amazon.ca/Hot-Selling-Brand-Ladies-...
# ICEBUG                NaN  https://www.amazon.ca/ICEBUG-55326-9E-L10-5-Sp...
# Leather               NaN  https://www.amazon.ca/Leather-Womens-Comfort-P...
# Leatherette           NaN  https://www.amazon.ca/Leatherette-Womens-Slipp...
# Linen                 NaN  https://www.amazon.ca/Linen-Womens-Comfort-Loa...
# Loffler               NaN  https://www.amazon.ca/Loffler-Womens-Leisure-S...
# Lopkey                NaN  https://www.amazon.ca/Lopkey-Reusable-Waterpro...
# MARLEY                NaN  http://www.amazon.ca/MARLEY-Leather-Block-Blac...
# Mirak                 NaN  http://www.amazon.co.uk/Mirak-Montana-Womens-L...
# Moking                NaN  http://www.amazon.ca/Moking-Fashion-Cotton-Jog...
# Nine                  NaN  http://www.amazon.ca/Nine-West-Womens-Speakup-...
# PEARL                 NaN  http://www.amazon.ca/PEARL-Suede-Stiletto-Elec...
# PEEPTOE               NaN  http://www.amazon.ca/PEEPTOE-Glitter-Stiletto-...
# Patent                NaN  http://www.amazon.ca/Patent-Leather-Stiletto-V...
# Pointed               NaN  https://www.amazon.ca/Pointed-Comfort-Leather-...
# RoundToe              NaN  https://www.amazon.ca/RoundToe-Platform-Fashio...
# Salomon               NaN  http://www.amazon.co.uk/Salomon-Synapse-hiking...
# SanSha                NaN  http://www.amazon.ca/SanSha-Hot-Selling-Ladies...
# Sockwell              NaN  http://www.amazon.com/Sockwell-Womens-Cushion-...
# Sparkling             NaN  https://www.amazon.ca/Sparkling-Glitter-Womens...
# Sperry                NaN  http://www.amazon.co.uk/Sperry-Top-Sider-Baham...
# Stretch               NaN  https://www.amazon.ca/Stretch-Fashion-Sneakers...
# Suede                 NaN  http://www.amazon.ca/Suede-Stiletto-Purple-Cou...
# Valanty               NaN  https://www.amazon.ca/Valanty-Stiletto-Platfor...
# Women                 NaN  https://www.amazon.ca/Women-Shoes-Loafers-Colo...
# Women%C2%A1%C2%AEs    NaN  https://www.amazon.ca/Women%C2%A1%C2%AEs-Platf...
# Women%C2%A1%C2%AFs    NaN  https://www.amazon.ca/Women%C2%A1%C2%AFs-Stile...
# Womens                NaN  https://www.amazon.ca/Womens-Comfort-Colors-av...
# XXL                   NaN  https://www.amazon.ca/XXL-travel-bag-holdall-b...
# YU                    NaN  https://www.amazon.ca/YU-Womens-Comfort-Colors...
# YUWomens              NaN  https://www.amazon.ca/YUWomens-Pointed-Loafers...
# Yonex                 NaN  https://www.amazon.ca/Yonex-Cushion-Badminton-...
# adidas                NaN  http://www.amazon.com/adidas-Duramo-Slide-M-Sl...

# %%
for i in range(0,len(shoes_strip["Stripcol"])):
    if shoes_strip["Stripcol"][i]=="Nine" :
        shoes_strip["brand"][i]="Nine West"

# %%
for i in range(0,len(shoes_strip["Stripcol"])):
    if shoes_strip["Stripcol"][i]=="Mirak" :
        shoes_strip["brand"][i]="Mirak Montana"

# %%
shoes_strip["brand"].isnull().sum()
# Out:
# 819

# %%
shoes_strip["brand"].fillna(100,inplace=True)    # now in order to replace "NaN" null value with our brand name lets first fill the null value with a number so that it can be used in conditional loops
# Out:
# C:\Users\Asus\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
shoes_strip.head()
# Out:
#     brand                                  prices.sourceURLs    Stripcol
# 0  Novica  https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 1  Novica  https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 2  Novica  https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 3  Novica  https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 4  Novica  https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock

# %%
x=len(shoes_strip["brand"])     # replacing the 100 with our required brand name

# %%
for i in range(0,x):
    for j in shoes_strip["Stripcol"]:
        if shoes_strip["brand"][i]==100:
            shoes_strip["brand"][i]=j
        break

# %%
shoes_strip["brand"].isnull().sum()
# Out:
# 0

# %%
shoes_strip.head()
# Out:
#     brand                                  prices.sourceURLs    Stripcol
# 0  Novica  https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 1  Novica  https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 2  Novica  https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 3  Novica  https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock
# 4  Novica  https://www.overstock.com/Worldstock-Fair-Trad...  Worldstock

# %%
shoes.head()
# Out:
#                      id   brand                               categories  \
# 0  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 1  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 2  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 3  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
# 4  AVpe__eOilAPnD_xSt-H  Novica  Access.,Clothing,Shoes,Women's Clothing
#
#    colors             dateAdded           dateUpdated  \
# 0  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 1  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 2  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 3  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
# 4  Purple  2017-02-03T22:06:24Z  2017-03-28T11:53:51Z
#
#                                         descriptions dimension  ean  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...       NaN  NaN
#
#                                             features imageURLs  \
# 0  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 1  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 2  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 3  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
# 4  [{"key":"Pattern","value":["Solid"]},{"key":"W...       NaN
#
#                                                 keys manufacturer  \
# 0  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 1  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 2  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 3  handcraftedalpacablendpurplecharismasweaterper...          NaN
# 4  handcraftedalpacablendpurplecharismasweaterper...          NaN
#
#   manufacturerNumber merchants  \
# 0             231516       NaN
# 1             231516       NaN
# 2             231516       NaN
# 3             231516       NaN
# 4             231516       NaN
#
#                                                 name  prices.amountMin  \
# 0  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 1  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 2  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 3  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
# 4  Handcrafted Alpaca Blend 'Purple Charisma' Swe...             62.99
#
#    prices.amountMax prices.availability prices.color prices.condition  \
# 0             62.99                 NaN          NaN              NaN
# 1             62.99                 NaN          NaN              NaN
# 2             62.99                 NaN          NaN              NaN
# 3             62.99                 NaN          NaN              NaN
# 4             62.99                 NaN          NaN              NaN
#
#   prices.currency      prices.dateAdded           prices.dateSeen  \
# 0             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 1             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 2             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 3             USD  2017-03-28T11:53:51Z  2017-03-26T05:04:46.539Z
# 4             USD  2017-03-02T16:48:44Z  2017-02-08T07:38:48.129Z
#
#    prices.isSale prices.merchant prices.offer prices.shipping prices.size  \
# 0          False   Overstock.com          NaN             NaN           L
# 1          False   Overstock.com          NaN             NaN           M
# 2          False   Overstock.com          NaN             NaN           S
# 3          False   Overstock.com          NaN             NaN          XL
# 4           True   Overstock.com          NaN             NaN          XL
#
#                                    prices.sourceURLs  \
# 0  https://www.overstock.com/Worldstock-Fair-Trad...
# 1  https://www.overstock.com/Worldstock-Fair-Trad...
# 2  https://www.overstock.com/Worldstock-Fair-Trad...
# 3  https://www.overstock.com/Worldstock-Fair-Trad...
# 4  https://www.overstock.com/Worldstock-Fair-Trad...
#
#                                           quantities  \
# 0  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 1  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 2  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 3  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
# 4  [{"dateSeen":["2017-03-26T05:04:46.539Z","2017...
#
#                                              reviews sizes  \
# 0  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 1  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 2  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 3  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
# 4  [{"date":"2017-01-10T00:00:00.000Z","dateAdded...   NaN
#
#                                                 skus  \
# 0  [{"sourceURLs":["https://www.overstock.com/Wor...
# 1  [{"sourceURLs":["https://www.overstock.com/Wor...
# 2  [{"sourceURLs":["https://www.overstock.com/Wor...
# 3  [{"sourceURLs":["https://www.overstock.com/Wor...
# 4  [{"sourceURLs":["https://www.overstock.com/Wor...
#
#                                           sourceURLs  upc  Average_Price
# 0  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 1  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 2  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 3  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99
# 4  https://www.overstock.com/Worldstock-Fair-Trad...  NaN          62.99

# %%
shoes.brand=shoes_strip.brand

# %%
shoes.brand.head()
# Out:
# 0    Novica
# 1    Novica
# 2    Novica
# 3    Novica
# 4    Novica
# Name: brand, dtype: object

# %%
shoes.brand.isnull().sum()
# Out:
# 0

# %%
shoes.colors.isnull().sum()
# Out:
# 13957

# %%
model_g = ols("Average_Price~brand",data=shoes).fit()

# %%
print(sms.stats.anova_lm(model_g))     # without sorting
# Out:
#                df        sum_sq        mean_sq          F  PR(>F)
# brand      1360.0  5.625886e+08  413668.116297  77.652343     0.0
# Residual  32440.0  1.728138e+08    5327.181388        NaN     NaN

# %%
shoes_sort=shoes.sort_values(by="brand")

# %%
model_g=ols("Average_Price~brand",data=shoes_sort).fit()   # after sorting

# %%
print(sms.stats.anova_lm(model_g))
# Out:
#                df        sum_sq        mean_sq          F  PR(>F)
# brand      1360.0  5.625886e+08  413668.116297  77.652343     0.0
# Residual  32440.0  1.728138e+08    5327.181388        NaN     NaN

# %%
# lets check the corelation between numeric columns
shoes_sort.corr()
# Out:
#                        ean  prices.amountMin  prices.amountMax  prices.isSale  \
# ean               1.000000          0.102093          0.102141      -0.024775
# prices.amountMin  0.102093          1.000000          0.963482      -0.128920
# prices.amountMax  0.102141          0.963482          1.000000      -0.128096
# prices.isSale    -0.024775         -0.128920         -0.128096       1.000000
# upc               0.998532          0.113582          0.113680      -0.009020
# Average_Price     0.102159          0.990490          0.991161      -0.129690
#
#                        upc  Average_Price
# ean               0.998532       0.102159
# prices.amountMin  0.113582       0.990490
# prices.amountMax  0.113680       0.991161
# prices.isSale    -0.009020      -0.129690
# upc               1.000000       0.113675
# Average_Price     0.113675       1.000000

# %%
sns.heatmap(shoes[["brand","prices.amountMax"]])

# %%
# Word Cloud of brand names

import os
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
from PIL import Image
wave_mask = np.array(Image.open( "C:\\Users\\Asus\\Pictures\\wave.jpg"))

# %%
list=[]
for i in shoes["brand"] :
    list.append(i)
slist = str(list)

wordcloud = WordCloud(width=400, height=200,mask=wave_mask).generate(slist)
plt.figure(figsize=(12,12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
shoes_scatter=shoes_avg.sort_values(by="Average_Price",ascending=False).head(5)

# %%
shoes_scatter
# Out:
#                    prices.amountMin  prices.amountMax  Average_Price  \
# brand
# JewelsObsession            3322.190          3322.190       3322.190
# Valentino                  1186.998          1186.998       1186.998
# Simone Rocha               1120.000          1120.000       1120.000
# MALONE SOULIERS            1100.000          1100.000       1100.000
# Nicholas Kirkwood          1095.000          1095.000       1095.000
#
#                    Price Gap
# brand
# JewelsObsession          0.0
# Valentino                0.0
# Simone Rocha             0.0
# MALONE SOULIERS          0.0
# Nicholas Kirkwood        0.0

# %%
# Top 10 Brands with highest Average Price
list1=[]
for i in shoes_scatter.index :
    list1.append(i)
slist1 = str(list1)

wordcloud = WordCloud(width=480, height=480, max_font_size=40, min_font_size=10).generate(slist1)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
# Much work is still remaining
